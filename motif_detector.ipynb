# %%
import torch

# %%
checkpoint = torch.load('./Models/ELK1_GM12878_ELK1_(1277-1)_Stanford.pth')

# %%
motif_detector = checkpoint['conv'][0] # -> the first motif detector among 16(=num_motif) detectors

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(motif_detector.cpu().detach().numpy())

# %%
df
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.252012  0.397320  0.056953 -0.202817 -0.053666  0.409154 -0.790845
# 1 -0.066461  0.314164 -0.089973  0.228751  0.188876 -0.796705  1.315804
# 2  0.316540 -0.171575 -0.796930 -0.141778 -0.095412 -0.710434 -0.249268
# 3 -0.017601 -0.145745 -0.218482 -0.112312 -0.314680 -0.177674 -0.657386
#
#          7         8         9   ...        14        15        16        17  \
# 0  0.511663  0.550259 -0.569926  ...  0.078495  1.757935 -1.010413 -0.809077
# 1 -1.442761  0.453990 -0.385055  ... -0.872049 -0.695909 -0.238886  1.045611
# 2  0.548438 -0.896235  0.223663  ...  0.611634 -0.071259 -1.097699 -0.413553
# 3  0.759738 -0.277962 -0.308715  ...  0.792325 -0.495363  0.673546  0.104463
#
#          18        19        20        21        22        23
# 0 -0.703498 -0.036685 -0.512454 -0.682816 -0.093100  0.148643
# 1 -0.278503  0.153679 -0.185226  0.629602 -0.304874 -0.082130
# ...
